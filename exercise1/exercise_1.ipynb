# %%
import numpy as np
import _pickle as cPickle
import os
import gzip

# %% [markdown]
# # First exercise: Classifying MNIST with MLPs
# In this exercise you will implement a Neural Network (or MLP) and classify the MNIST digits with it.
# MNIST is a "well hung" dataset that has been used a lot over the years to benchmark different classification algorithms.
# To learn more about it have a look here: http://yann.lecun.com/exdb/mnist/ .

# %% [markdown]
# # Data Loading
# We first define a function for downloading and loading MNIST.
# **WARNING**: Executing it will obviously use up some space on your machine ;).

# %%
def mnist(datasets_dir='./data'):
    if not os.path.exists(datasets_dir):
        os.mkdir(datasets_dir)
    data_file = os.path.join(datasets_dir, 'mnist.pkl.gz')
    if not os.path.exists(data_file):
        print('... downloading MNIST from the web')
        try:
            import urllib
            urllib.urlretrieve('http://google.com')
        except AttributeError:
            import urllib.request as urllib
        url = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
        urllib.urlretrieve(url, data_file)

    print('... loading data')
    # Load the dataset
    f = gzip.open(data_file, 'rb')
    try:
        train_set, valid_set, test_set = cPickle.load(f, encoding="latin1")
    except TypeError:
        train_set, valid_set, test_set = cPickle.load(f)
    f.close()

    test_x, test_y = test_set
    test_x = test_x.astype('float32')
    test_x = test_x.astype('float32').reshape(test_x.shape[0], 1, 28, 28)
    test_y = test_y.astype('int32')
    valid_x, valid_y = valid_set
    valid_x = valid_x.astype('float32')
    valid_x = valid_x.astype('float32').reshape(valid_x.shape[0], 1, 28, 28)
    valid_y = valid_y.astype('int32')
    train_x, train_y = train_set
    train_x = train_x.astype('float32').reshape(train_x.shape[0], 1, 28, 28)
    train_y = train_y.astype('int32')
    rval = [(train_x, train_y), (valid_x, valid_y), (test_x, test_y)]
    print('... done loading data')
    return rval

# %% [markdown]
# # Neural Network Layers
# We now define "bare bone" neural network layers.
# The parts marked with **TODO** are where you should finish the implementation!
# Conceptually we will implement the layers as follows:
#
# Each layer has a constructor that takes an input layer plus some additional arguments such as layer size and the activation function name. The layer then uses the provided input layer to compute the layer dimensions, weight shapes, etc. and setup all auxilliary variables.
#
# Each layer then has to provide three functions (as defined in the Layer class below): *output_shape()*, *fprop()* and *brop()*. The output_shape function is used to figure out the shape for the next layer and the *fprop()/bprop()* functions are used to compute forward and backward passes through the network.

# %%
# start by defining simple helpers
def sigmoid(x):
    return 1.0/(1.0+np.exp(-x))

def sigmoid_d(x):
    return sigmoid(x) * (1-sigmoid(x))

def tanh(x):
    return np.tanh(x)

def tanh_d(x):
    return 1 - tanh(x)**2

def relu(x):
    return np.maximum(0.0, x)

def relu_d(x):
    return np.where( x > 0, 1, 0)

def softmax(x, axis=1):
    # to make the softmax a "safe" operation we will 
    # first subtract the maximum along the specified axis
    # so that np.exp(x) does not blow up!
    # Note that this does not change the output.
    x_max = np.max(x, axis=axis, keepdims=True)
    x_safe = x - x_max
    e_x = np.exp(x_safe)
    return e_x / np.sum(e_x, axis=axis, keepdims=True)

def one_hot(labels):
    """this creates a one hot encoding from a flat vector:
    i.e. given y = [0,2,1]
     it creates y_one_hot = [[1,0,0], [0,0,1], [0,1,0]]
    """
    classes = np.unique(labels)
    n_classes = classes.size
    one_hot_labels = np.zeros(labels.shape + (n_classes,))
    for c in classes:
        one_hot_labels[labels == c, c] = 1
    return one_hot_labels

def unhot(one_hot_labels):
    """ Invert a one hot encoding, creating a flat vector """
    return np.argmax(one_hot_labels, axis=-1)

# then define an activation function class
class Activation(object):
    
    def __init__(self, tname):
        if tname == 'sigmoid':
            self.act = sigmoid
            self.act_d = sigmoid_d
        elif tname == 'tanh':
            self.act = tanh
            self.act_d = tanh_d
        elif tname == 'relu':
            self.act = relu
            self.act_d = relu_d
        else:
            raise ValueError('Invalid activation function.')
            
    def fprop(self, input):
        # we need to remember the last input
        # so that we can calculate the derivative with respect
        # to it later on
        self.last_input = input
        return self.act(input)
    
    def bprop(self, output_grad):
        return output_grad * self.act_d(self.last_input)

# define a base class for layers
class Layer(object):
    
    def fprop(self, input):
        """ Calculate layer output for given input 
            (forward propagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def bprop(self, output_grad):
        """ Calculate input gradient and gradient 
            with respect to weights and bias (backpropagation). 
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def output_size(self):
        """ Calculate size of this layer's output.
        input_shape[0] is the number of samples in the input.
        input_shape[1:] is the shape of the feature.
        """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for loss outputs
# an output layer can then simply be derived
# from both Layer and Loss 
class Loss(object):

    def loss(self, output, output_net):
        """ Calculate mean loss given real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

    def input_grad(self, output, output_net):
        """ Calculate input gradient real output and network output. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a base class for parameterized things        
class Parameterized(object):
    
    def params(self):
        """ Return parameters (by reference) """
        raise NotImplementedError('This is an interface class, please use a derived instance')
    
    def grad_params(self):
        """ Return accumulated gradient with respect to params. """
        raise NotImplementedError('This is an interface class, please use a derived instance')

# define a container for providing input to the network
class InputLayer(Layer):
    
    def __init__(self, input_shape):
        if not isinstance(input_shape, tuple):
            raise ValueError("InputLayer requires input_shape as a tuple")
        self.input_shape = input_shape

    def output_size(self):
        return self.input_shape
    
    def fprop(self, input):
        return input
    
    def bprop(self, output_grad):
        return output_grad
        
class FullyConnectedLayer(Layer, Parameterized):
    """ A standard fully connected hidden layer, as discussed in the lecture.
    """
    
    def __init__(self, input_layer, num_units, 
                 init_stddev, activation_fun=Activation('relu')):
        self.num_units = num_units
        self.activation_fun = activation_fun
        # the input shape will be of size (batch_size, num_units_prev) 
        # where num_units_prev is the number of units in the input 
        # (previous) layer
        self.input_shape = input_layer.output_size()
        # weight initialization
        # this is the weight matrix it should have shape: (num_units_prev, num_units)
        self.W = np.random.normal(0,init_stddev,(self.input_shape[1], num_units))
        # and this is the bias vector of shape: (num_units)
        self.b = np.random.normal(0, init_stddev, num_units)
        # create dummy variables for parameter gradients
        # no need to change these here!
        self.dW = None
        self.db = None
    
    def output_size(self):
        return (self.input_shape[0], self.num_units)
    
    def fprop(self, input):
        # forward propagation
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        #       then this is simply a linear layer
        # you again want to cache the last_input for the bprop
        # implementation below!
        self.last_input = input
        # NOTE: Use numpy dot product
        # h = t(a), a = W * x + b 
        a = np.dot(input, self.W) + self.b
        if self.activation_fun is None:
            return a
        else:
            return self.activation_fun.fprop(a)
        
    def bprop(self, output_grad):
        """ Calculate input gradient (backpropagation). """
        # implement backward propagation
        
        # HINT: you may have to divide dW and db by n
        #       to make gradient checking work 
        #       OR you divide the gradient in the output layer by n
        n = output_grad.shape[0]
        # accumulate gradient wrt. the parameters first
        # we will need to store these to later update
        # the network after a few forward backward passes
        # NOTE: you should also handle the case were 
        #       activation_fun is None (meaning no activation)
        if self.activation_fun is not None:
            output_grad = self.activation_fun.bprop(output_grad)
            
        # the gradient wrt. W should be stored as self.dW
        # the gradient wrt. b should be stored as selfdb
        # NOTE: self.dW is also a numpy dot product
        self.dW = np.dot(self.last_input.T, output_grad) * (1/n)
        self.db = np.sum(output_grad, axis=0, keepdims = True) * (1/n)
        # the gradient wrt. the input should be calculated here
        grad_input = np.dot(output_grad, self.W.T)
        return grad_input
        
    def params(self):
        return self.W, self.b

    def grad_params(self):
        return self.dW, self.db

# finally we specify the interface for output layers 
# which are layers that also have a loss function
# we will implement two output layers:
#  a Linear, and Softmax (Logistic Regression) layer
# The difference between output layers and and normal 
# layers is that they will be called to compute the gradient
# of the loss through input_grad(). bprop will never 
# be called on them!
class LinearOutput(Layer, Loss):
    """ A simple linear output layer that  
        uses a squared loss (e.g. should be used for regression)
    """
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
        
    def fprop(self, input):
        return input

    def bprop(self, output_grad):
        raise NotImplementedError(
            'LinearOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # implement gradient of squared loss
        return (Y_pred - Y)

    def loss(self, Y, Y_pred):
        loss = 0.5 * np.square(Y_pred - Y)
        return np.mean(np.sum(loss, axis=1))

class SoftmaxOutput(Layer, Loss):
    """ A softmax output layer that calculates 
        the negative log likelihood as loss
        and should be used for classification.
    """
    
    def __init__(self, input_layer):
        self.input_size = input_layer.output_size()
        
    def output_size(self):
        return (1,)
    
    def fprop(self, input):
        return softmax(input)
    
    def bprop(self, output_grad):
        raise NotImplementedError(
            'SoftmaxOutput should only be used as the last layer of a Network'
            + ' bprop() should thus never be called on it!'
        )
    
    def input_grad(self, Y, Y_pred):
        # implement gradient of the negative log likelihood loss
        # HINT: since this would involve taking the log 
        #       of the softmax (which is np.exp(x)/np.sum(x, axis=1))
        #       this gradient computation can be simplified a lot,
        #       you may find a connection to the LinearOutput layer!
        return Y_pred - Y

    def loss(self, Y, Y_pred):
        # Assume one-hot encoding of Y
        out = Y_pred
        # to make the loss numerically stable 
        # you should add an epsilon in the log ;)
        eps = 1e-10
        # calculate negative log likelihood
        loss = np.sum(-np.log(Y_pred + eps) * Y, axis=1)
        return np.mean(loss)

# %% [markdown]
# # Neural Network class
# With all layers in place (and properly implemented by you) we can finally define a neural network.
# For our purposes a neural network is simply a collection of layers which we will cycle through and on which we will call fprop and bprop to compute partial derivatives with respect to the input and the parameters.
#
# Pay special attention to the *check_gradients()* function in which you should implement automatic differentiation. This function will become your best friend when checking the correctness of your implementation.

# %%
class NeuralNetwork:
    """ Our Neural Network container class.
    """
    def __init__(self, layers):
        self.layers = layers
        
    def _loss(self, X, Y):
        Y_pred = self.predict(X)
        return self.layers[-1].loss(Y, Y_pred)

    def predict(self, X):
        """ Calculate an output Y for the given input X. """
        # implement forward pass through all layers
            
        for layer in self.layers:
            Y_pred = layer.fprop(X)
            X = Y_pred
            
        return Y_pred
    
    def backpropagate(self, Y, Y_pred, upto=0):
        """ Backpropagation of partial derivatives through 
            the complete network up to layer 'upto'
        """
        next_grad = self.layers[-1].input_grad(Y, Y_pred)
        # implement backward pass through all layers        
        for layer in self.layers[upto:-1][::-1]:
            next_grad = layer.bprop(next_grad)
        
        return next_grad
    
    def classification_error(self, X, Y):
        """ Calculate error on the given data 
            assuming they are classes that should be predicted. 
        """
        Y_pred = unhot(self.predict(X))
        error = Y_pred != Y
        return np.mean(error)
    
    def sgd_epoch(self, X, Y, learning_rate, batch_size):
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        for b in range(n_batches):
            # Implement stochastic gradient descent here
    
            # start by extracting a batch from X and Y
            # (you can assume the inputs are already shuffled)
            
            start = b * batch_size
            end = start + batch_size
            
            X_batch = X[start:end,]
            Y_batch = Y[start:end,]
            
            # then forward and backward propagation + updates
            # HINT: layer.params() returns parameters *by reference*
            #       so you can easily update in-place
            Y_pred = self.predict(X_batch)
            self.backpropagate(Y_batch,Y_pred)
            
            for layer in self.layers[1:-1]:
                W, b = layer.params()
                dW, db = layer.grad_params()
                layer.W = W - learning_rate * dW
                layer.b = b - learning_rate * db
            
    
    def gd_epoch(self, X, Y, learning_rate, batch_size):
        # Implement batch gradient descent here
        # A few hints:
        #   There are two strategies you can follow:
        #   Either shove the whole dataset through the network
        #   at once (which can be problematic for large datasets)
        #   or run through it batch wise as in the sgd approach
        #   and accumulate the gradients for all parameters as
        #   you go through the data. Either way you should then
        #   do one gradient step after you went through the
        #   complete dataset!
        
        # is this right?
        #n_samples = X.shape[0]
        #n_batches = n_samples // batch_size
        #for b in range(n_batches):           
        #    start = b * batch_size
        #    end = start + batch_size
        #    
        #    X_batch = X[start:end,]
        #    Y_batch = Y[start:end,]
        #    
        #    Y_pred = self.predict(X_batch)
        #    self.backpropagate(Y_batch,Y_pred)
        #    
        #for layer in self.layers[1:-1]:
        #    W, b = layer.params()
        #    dW, db = layer.grad_params()
        #    layer.W = W - learning_rate * dW
        #    layer.b = b - learning_rate * db
        
        Y_pred = self.predict(X)
        self.backpropagate(Y,Y_pred)
        
        for layer in self.layers[1:-1]:
            W, b = layer.params()
            dW, db = layer.grad_params()
            layer.W = W - learning_rate * dW
            layer.b = b - learning_rate * db
    
    def train(self, X, Y, X_valid, Y_valid, learning_rate=0.1, max_epochs=100, batch_size=64,
              descent_type="sgd", y_one_hot=True):

        """ Train network on the given data. """
        n_samples = X.shape[0]
        n_batches = n_samples // batch_size
        
        self.train_loss = []
        self.valid_loss = []
        self.train_error = []
        self.valid_error = []
          
        if y_one_hot:
            Y_train = one_hot(Y)
            Y_valid_hot = one_hot(Y_valid)
        else:
            Y_train = Y
        print("... starting training")
        for e in range(max_epochs+1):
            if descent_type == "sgd":
                self.sgd_epoch(X, Y_train, learning_rate, batch_size)
            elif descent_type == "gd":
                self.gd_epoch(X, Y_train, learning_rate, batch_size)
            else:
                raise NotImplementedError("Unknown gradient descent type {}".format(descent_type))

            # Output error on the training data
            train_loss = self._loss(X, Y_train)
            train_error = self.classification_error(X, Y)
            print('epoch {:.4f}, loss {:.4f}, train error {:.4f}'.format(e, train_loss, train_error))
            self.train_loss.append(train_loss)
            self.train_error.append(train_error)
            
            # compute error on validation data:
            # simply make the function take validation data as input
            # and then compute errors here and print them
            validation_loss = self._loss(X_valid, Y_valid_hot)
            validation_error = self.classification_error(X_valid, Y_valid)
            print('epoch {:.4f}, validation loss {:.4f}, validation error {:.4f}'.format(e, validation_loss, validation_error))
            self.valid_loss.append(validation_loss)
            self.valid_error.append(validation_error)
    
    def check_gradients(self, X, Y):
        """ Helper function to test the parameter gradients for
        correctness. """
        for l, layer in enumerate(self.layers):
            if isinstance(layer, Parameterized):
                print('checking gradient for layer {}'.format(l))
                for p, param in enumerate(layer.params()):
                    # we iterate through all parameters
                    param_shape = param.shape
                    # define functions for conveniently swapping
                    # out parameters of this specific layer and 
                    # computing loss and gradient with these 
                    # changed parametrs
                    def output_given_params(param_new):
                        """ A function that will compute the output 
                            of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # return computed loss
                        return self._loss(X, Y)

                    def grad_given_params(param_new):
                        """A function that will compute the gradient 
                           of the network given a set of parameters
                        """
                        # copy provided parameters
                        param[:] = np.reshape(param_new, param_shape)
                        # Forward propagation through the net
                        Y_pred = self.predict(X)
                        # Backpropagation of partial derivatives
                        self.backpropagate(Y, Y_pred, upto=l)
                        # return the computed gradient 
                        return np.ravel(self.layers[l].grad_params()[p])

                    # let the initial parameters be the ones that
                    # are currently placed in the network and flatten them
                    # to a vector for convenient comparisons, printing etc.
                    param_init = np.ravel(np.copy(param))
                    
                    # To debug you network's gradients use scipys
                    # gradient checking!
                    epsilon = 1e-5
                    import scipy.optimize
                    err = scipy.optimize.check_grad(output_given_params, 
                          grad_given_params, param_init) 
                    print('diff scipy {:.2e}'.format(err))
                    assert(err < epsilon)
                    
                    # reset the parameters to their initial values
                    param[:] = np.reshape(param_init, param_shape)

# %% [markdown]
# # Gradient Checking
# After implementing everything it is always a good idea to setup some layers and perform gradient
# checking on random data. **Note** that this is only an example! It is not a useful network architecture ;). We also expect you to play around with this to test all your implemented components.

# %%
input_shape = (5, 10)
n_labels = 6
layers = [InputLayer(input_shape)]

layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=15,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=6,
                init_stddev=0.1,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=n_labels,
                init_stddev=0.1,
                activation_fun=Activation('relu')
))
layers.append(SoftmaxOutput(layers[-1]))
nn = NeuralNetwork(layers)

# %%
# create random data
X = np.random.normal(size=input_shape)
# and random labels
Y = np.zeros((input_shape[0], n_labels))
for i in range(Y.shape[0]):
    idx = np.random.randint(n_labels)
    Y[i, idx] = 1.

# %%
nn.check_gradients(X, Y)
# Out:
# checking gradient for layer 1
# diff scipy 1.12e-07
# diff scipy 3.77e-08
# checking gradient for layer 2
# diff scipy 8.47e-08
# diff scipy 3.08e-08
# checking gradient for layer 3
# diff scipy 3.56e-08
# diff scipy 1.14e-08

# %% [markdown]
# # Training on MNIST
# Finally we can let our network run on the MNIST dataset!

# %% [markdown]
# First load the data and reshape it.

# %%
# load
Dtrain, Dval, Dtest = mnist()
X_train, y_train = Dtrain
X_valid, y_valid = Dval
X_test, y_test = Dtest
# Out:
# ... loading data
# ... done loading data

# %% [markdown]
# *Dtrain* contains 50k images which are of size 28 x 28 pixels. Hence:

# %%
print("X_train shape: {}".format(np.shape(X_train)))
print("y_train shape: {}".format(np.shape(y_train)))
# Out:
# X_train shape: (50000, 1, 28, 28)
# y_train shape: (50000,)

# %% [markdown]
# y_train will automatically be converted in the *train()* function to one_hot encoding.
#
#
# But we need to reshape X_train, as our Network expects flat vectors of size 28*28 as input!

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
print("Reshaped X_train size: {}".format(X_train.shape))
X_valid = X_valid.reshape((X_valid.shape[0], -1))
print("Reshaped X_valid size: {}".format(X_valid.shape))
X_test = X_test.reshape((X_test.shape[0], -1))
print("Reshaped X_test size: {}".format(X_test.shape))
# Out:
# Reshaped X_train size: (50000, 784)
# Reshaped X_valid size: (10000, 784)
# Reshaped X_test size: (10000, 784)

# %% [markdown]
# Ah, much better ;-)!
#
# Now we can finally really start training a Network!
#
#
# I pre-defined a small Network for you below. Again This is not really a good default and will not produce state of the art results. Please play around with this a bit. See how different activation functions and training procedures (gd / sgd) affect the result.

# %%
import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=300,
                init_stddev=0.01,
                activation_fun=Activation('tanh')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=200,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
# Train neural network
t0 = time.time()
max_epochs=10
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.4, 
         max_epochs=max_epochs, batch_size=64, descent_type="sgd", y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# epoch 0.0000, loss 0.2489, train error 0.0800
# epoch 0.0000, validation loss 0.2354, validation error 0.0724
# epoch 1.0000, loss 0.1473, train error 0.0470
# epoch 1.0000, validation loss 0.1531, validation error 0.0450
# epoch 2.0000, loss 0.1089, train error 0.0354
# epoch 2.0000, validation loss 0.1284, validation error 0.0376
# epoch 3.0000, loss 0.0892, train error 0.0290
# epoch 3.0000, validation loss 0.1206, validation error 0.0358
# epoch 4.0000, loss 0.0719, train error 0.0239
# epoch 4.0000, validation loss 0.1108, validation error 0.0307
# epoch 5.0000, loss 0.0578, train error 0.0189
# epoch 5.0000, validation loss 0.1062, validation error 0.0293
# epoch 6.0000, loss 0.0518, train error 0.0174
# epoch 6.0000, validation loss 0.1060, validation error 0.0275
# epoch 7.0000, loss 0.0506, train error 0.0173
# epoch 7.0000, validation loss 0.1128, validation error 0.0291
# epoch 8.0000, loss 0.0294, train error 0.0101
# epoch 8.0000, validation loss 0.1028, validation error 0.0258
# epoch 9.0000, loss 0.0223, train error 0.0076
# epoch 9.0000, validation loss 0.0997, validation error 0.0239
# epoch 10.0000, loss 0.0264, train error 0.0091
# epoch 10.0000, validation loss 0.1134, validation error 0.0269
# Duration: 230.4s

# %% [markdown]
# # Figure out a reasonable Network that achieves good performance
# As the last part of this task, setup a network that works well and gets reasonable accuracy, say ~ 1-3 percent error on the **validation set**.
# Train this network on the complete data and compute the **test error**.
#
# Visualize the validation loss and training loss for each iteration in a plot, e.g. using matplotlib

# %%
import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=220,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn = NeuralNetwork(layers)
# Train neural network
t0 = time.time()
max_epochs=30
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.15, 
         max_epochs=max_epochs, batch_size=30, descent_type="sgd", y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# epoch 0.0000, loss 0.1878, train error 0.0570
# epoch 0.0000, validation loss 0.1798, validation error 0.0507
# epoch 1.0000, loss 0.1161, train error 0.0348
# epoch 1.0000, validation loss 0.1239, validation error 0.0339
# epoch 2.0000, loss 0.0870, train error 0.0262
# epoch 2.0000, validation loss 0.1038, validation error 0.0304
# epoch 3.0000, loss 0.0690, train error 0.0207
# epoch 3.0000, validation loss 0.0939, validation error 0.0281
# epoch 4.0000, loss 0.0554, train error 0.0169
# epoch 4.0000, validation loss 0.0867, validation error 0.0266
# epoch 5.0000, loss 0.0468, train error 0.0140
# epoch 5.0000, validation loss 0.0842, validation error 0.0251
# epoch 6.0000, loss 0.0410, train error 0.0125
# epoch 6.0000, validation loss 0.0828, validation error 0.0255
# epoch 7.0000, loss 0.0340, train error 0.0103
# epoch 7.0000, validation loss 0.0819, validation error 0.0245
# epoch 8.0000, loss 0.0282, train error 0.0083
# epoch 8.0000, validation loss 0.0797, validation error 0.0230
# epoch 9.0000, loss 0.0218, train error 0.0057
# epoch 9.0000, validation loss 0.0770, validation error 0.0232
# epoch 10.0000, loss 0.0182, train error 0.0046
# epoch 10.0000, validation loss 0.0758, validation error 0.0223
# epoch 11.0000, loss 0.0156, train error 0.0041
# epoch 11.0000, validation loss 0.0755, validation error 0.0221
# epoch 12.0000, loss 0.0135, train error 0.0035
# epoch 12.0000, validation loss 0.0753, validation error 0.0212
# epoch 13.0000, loss 0.0119, train error 0.0031
# epoch 13.0000, validation loss 0.0756, validation error 0.0211
# epoch 14.0000, loss 0.0105, train error 0.0025
# epoch 14.0000, validation loss 0.0760, validation error 0.0211
# epoch 15.0000, loss 0.0092, train error 0.0020
# epoch 15.0000, validation loss 0.0759, validation error 0.0206
# epoch 16.0000, loss 0.0081, train error 0.0016
# epoch 16.0000, validation loss 0.0757, validation error 0.0203
# epoch 17.0000, loss 0.0071, train error 0.0013
# epoch 17.0000, validation loss 0.0757, validation error 0.0201
# epoch 18.0000, loss 0.0062, train error 0.0010
# epoch 18.0000, validation loss 0.0752, validation error 0.0198
# epoch 19.0000, loss 0.0056, train error 0.0009
# epoch 19.0000, validation loss 0.0753, validation error 0.0193
# epoch 20.0000, loss 0.0049, train error 0.0006
# epoch 20.0000, validation loss 0.0751, validation error 0.0191
# epoch 21.0000, loss 0.0044, train error 0.0005
# epoch 21.0000, validation loss 0.0752, validation error 0.0190
# epoch 22.0000, loss 0.0039, train error 0.0004
# epoch 22.0000, validation loss 0.0752, validation error 0.0191
# epoch 23.0000, loss 0.0035, train error 0.0004
# epoch 23.0000, validation loss 0.0753, validation error 0.0192
# epoch 24.0000, loss 0.0032, train error 0.0003
# epoch 24.0000, validation loss 0.0754, validation error 0.0187
# epoch 25.0000, loss 0.0029, train error 0.0002
# epoch 25.0000, validation loss 0.0753, validation error 0.0187
# epoch 26.0000, loss 0.0026, train error 0.0002
# epoch 26.0000, validation loss 0.0755, validation error 0.0188
# epoch 27.0000, loss 0.0024, train error 0.0001
# epoch 27.0000, validation loss 0.0757, validation error 0.0187
# epoch 28.0000, loss 0.0022, train error 0.0001
# epoch 28.0000, validation loss 0.0758, validation error 0.0187
# epoch 29.0000, loss 0.0021, train error 0.0001
# epoch 29.0000, validation loss 0.0759, validation error 0.0186
# epoch 30.0000, loss 0.0019, train error 0.0001
# epoch 30.0000, validation loss 0.0761, validation error 0.0186
# Duration: 683.0s

# %%
# errors
train_error = nn.train_error
valid_error = nn.valid_error

test_error = nn.classification_error(X_test, y_test)
print('test error: {:.4f}'.format(test_error))
# Out:
# test error: 0.0196

# %%
import matplotlib.pyplot as plt

epochs = np.arange(0, max_epochs+1)
plt.plot(epochs, train_error, label = "train")
plt.plot(epochs, valid_error, label = "valid")

plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("error")
plt.legend()
plt.title("Training and Validation Error")


plt.savefig('report/plots/train_valid_error.png', dpi=150)
plt.show()

# %%
X_full = np.concatenate((X_train, X_valid))
y_full = np.concatenate((y_train, y_valid))

import time

# Setup a small MLP / Neural Network
# we can set the first shape to None here to indicate that
# we will input a variable number inputs to the network
input_shape = (None, 28*28)
layers = [InputLayer(input_shape)]
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=220,
                init_stddev=0.01,
                activation_fun=Activation('relu')
))
layers.append(FullyConnectedLayer(
                layers[-1],
                num_units=10,
                init_stddev=0.01,
                # last layer has no nonlinearity 
                # (softmax will be applied in the output layer)
                activation_fun=None 
))
layers.append(SoftmaxOutput(layers[-1]))

nn_full = NeuralNetwork(layers)
# Train neural network
t0 = time.time()
max_epochs=30
nn_full.train(X_full, y_full, X_test, y_test, learning_rate=0.15, 
         max_epochs=max_epochs, batch_size=30, descent_type="sgd", y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
# Out:
# ... starting training
# epoch 0.0000, loss 0.1688, train error 0.0528
# epoch 0.0000, validation loss 0.1692, validation error 0.0530
# epoch 1.0000, loss 0.1050, train error 0.0322
# epoch 1.0000, validation loss 0.1151, validation error 0.0353
# epoch 2.0000, loss 0.0779, train error 0.0248
# epoch 2.0000, validation loss 0.0968, validation error 0.0307
# epoch 3.0000, loss 0.0598, train error 0.0190
# epoch 3.0000, validation loss 0.0860, validation error 0.0274
# epoch 4.0000, loss 0.0493, train error 0.0156
# epoch 4.0000, validation loss 0.0820, validation error 0.0262
# epoch 5.0000, loss 0.0418, train error 0.0132
# epoch 5.0000, validation loss 0.0799, validation error 0.0245
# epoch 6.0000, loss 0.0352, train error 0.0111
# epoch 6.0000, validation loss 0.0774, validation error 0.0245
# epoch 7.0000, loss 0.0295, train error 0.0093
# epoch 7.0000, validation loss 0.0761, validation error 0.0235
# epoch 8.0000, loss 0.0239, train error 0.0073
# epoch 8.0000, validation loss 0.0737, validation error 0.0229
# epoch 9.0000, loss 0.0204, train error 0.0061
# epoch 9.0000, validation loss 0.0738, validation error 0.0228
# epoch 10.0000, loss 0.0170, train error 0.0050
# epoch 10.0000, validation loss 0.0730, validation error 0.0221
# epoch 11.0000, loss 0.0151, train error 0.0042
# epoch 11.0000, validation loss 0.0731, validation error 0.0220
# epoch 12.0000, loss 0.0136, train error 0.0038
# epoch 12.0000, validation loss 0.0734, validation error 0.0213
# epoch 13.0000, loss 0.0126, train error 0.0035
# epoch 13.0000, validation loss 0.0749, validation error 0.0214
# epoch 14.0000, loss 0.0110, train error 0.0028
# epoch 14.0000, validation loss 0.0745, validation error 0.0208
# epoch 15.0000, loss 0.0098, train error 0.0023
# epoch 15.0000, validation loss 0.0742, validation error 0.0208
# epoch 16.0000, loss 0.0084, train error 0.0018
# epoch 16.0000, validation loss 0.0739, validation error 0.0203
# epoch 17.0000, loss 0.0071, train error 0.0014
# epoch 17.0000, validation loss 0.0728, validation error 0.0197
# epoch 18.0000, loss 0.0058, train error 0.0010
# epoch 18.0000, validation loss 0.0717, validation error 0.0187
# epoch 19.0000, loss 0.0049, train error 0.0006
# epoch 19.0000, validation loss 0.0709, validation error 0.0187
# epoch 20.0000, loss 0.0044, train error 0.0005
# epoch 20.0000, validation loss 0.0710, validation error 0.0185
# epoch 21.0000, loss 0.0040, train error 0.0004
# epoch 21.0000, validation loss 0.0712, validation error 0.0183
# epoch 22.0000, loss 0.0035, train error 0.0004
# epoch 22.0000, validation loss 0.0712, validation error 0.0181
# epoch 23.0000, loss 0.0031, train error 0.0003
# epoch 23.0000, validation loss 0.0712, validation error 0.0178
# epoch 24.0000, loss 0.0029, train error 0.0003
# epoch 24.0000, validation loss 0.0713, validation error 0.0179
# epoch 25.0000, loss 0.0026, train error 0.0002
# epoch 25.0000, validation loss 0.0713, validation error 0.0176
# epoch 26.0000, loss 0.0024, train error 0.0001
# epoch 26.0000, validation loss 0.0714, validation error 0.0179
# epoch 27.0000, loss 0.0022, train error 0.0001
# epoch 27.0000, validation loss 0.0715, validation error 0.0179
# epoch 28.0000, loss 0.0020, train error 0.0000
# epoch 28.0000, validation loss 0.0717, validation error 0.0178
# epoch 29.0000, loss 0.0019, train error 0.0000
# epoch 29.0000, validation loss 0.0719, validation error 0.0178
# epoch 30.0000, loss 0.0017, train error 0.0000
# epoch 30.0000, validation loss 0.0719, validation error 0.0173
# Duration: 789.6s

# %%
train_error = nn_full.train_error
test_error = nn_full.valid_error

test_error = nn_full.classification_error(X_test, y_test)
print('test error: {:.4f}'.format(test_error))
# Out:
# test error: 0.0173

# %% [markdown]
# #### Test different Optimizations

# %%
import time

def model():
    input_shape = (None, 28*28)
    layers = [InputLayer(input_shape)]
    layers.append(FullyConnectedLayer(
                    layers[-1],
                    num_units=220,
                    init_stddev=0.01,
                    activation_fun=Activation('relu')
    ))
    layers.append(FullyConnectedLayer(
                    layers[-1],
                    num_units=10,
                    init_stddev=0.01,
                    # last layer has no nonlinearity 
                    # (softmax will be applied in the output layer)
                    activation_fun=None 
    ))
    layers.append(SoftmaxOutput(layers[-1]))
    
    return NeuralNetwork(layers)



# gradient descent
nn = model()
# Train neural network
t0 = time.time()
max_epochs=30
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.15, 
         max_epochs=max_epochs, batch_size=30, descent_type="gd", y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
gd_train_error = nn.train_error

# stochastic gradient descent
nn = model()
# Train neural network
t0 = time.time()
max_epochs=30
nn.train(X_train, y_train, X_valid, y_valid, learning_rate=0.15, 
         max_epochs=max_epochs, batch_size=30, descent_type="sgd", y_one_hot=True)
t1 = time.time()
print('Duration: {:.1f}s'.format(t1-t0))
sgd_train_error = nn.train_error
# Out:
# ... starting training
# epoch 0.0000, loss 2.3008, train error 0.8939
# epoch 0.0000, validation loss 2.3008, validation error 0.8926
# epoch 1.0000, loss 2.2982, train error 0.8365
# epoch 1.0000, validation loss 2.2981, validation error 0.8266
# epoch 2.0000, loss 2.2955, train error 0.7629
# epoch 2.0000, validation loss 2.2954, validation error 0.7551
# epoch 3.0000, loss 2.2927, train error 0.6937
# epoch 3.0000, validation loss 2.2925, validation error 0.6835
# epoch 4.0000, loss 2.2897, train error 0.6389
# epoch 4.0000, validation loss 2.2895, validation error 0.6259
# epoch 5.0000, loss 2.2865, train error 0.5955
# epoch 5.0000, validation loss 2.2862, validation error 0.5770
# epoch 6.0000, loss 2.2830, train error 0.5592
# epoch 6.0000, validation loss 2.2827, validation error 0.5387
# epoch 7.0000, loss 2.2792, train error 0.5278
# epoch 7.0000, validation loss 2.2788, validation error 0.5071
# epoch 8.0000, loss 2.2750, train error 0.5032
# epoch 8.0000, validation loss 2.2745, validation error 0.4821
# epoch 9.0000, loss 2.2703, train error 0.4815
# epoch 9.0000, validation loss 2.2697, validation error 0.4609
# epoch 10.0000, loss 2.2651, train error 0.4647
# epoch 10.0000, validation loss 2.2645, validation error 0.4436
# epoch 11.0000, loss 2.2594, train error 0.4526
# epoch 11.0000, validation loss 2.2586, validation error 0.4325
# epoch 12.0000, loss 2.2530, train error 0.4450
# epoch 12.0000, validation loss 2.2521, validation error 0.4252
# epoch 13.0000, loss 2.2458, train error 0.4382
# epoch 13.0000, validation loss 2.2449, validation error 0.4198
# epoch 14.0000, loss 2.2379, train error 0.4341
# epoch 14.0000, validation loss 2.2368, validation error 0.4169
# epoch 15.0000, loss 2.2291, train error 0.4311
# epoch 15.0000, validation loss 2.2278, validation error 0.4119
# epoch 16.0000, loss 2.2193, train error 0.4284
# epoch 16.0000, validation loss 2.2179, validation error 0.4111
# epoch 17.0000, loss 2.2085, train error 0.4259
# epoch 17.0000, validation loss 2.2069, validation error 0.4097
# epoch 18.0000, loss 2.1965, train error 0.4240
# epoch 18.0000, validation loss 2.1946, validation error 0.4082
# epoch 19.0000, loss 2.1832, train error 0.4218
# epoch 19.0000, validation loss 2.1811, validation error 0.4060
# epoch 20.0000, loss 2.1686, train error 0.4187
# epoch 20.0000, validation loss 2.1663, validation error 0.4016
# epoch 21.0000, loss 2.1526, train error 0.4140
# epoch 21.0000, validation loss 2.1499, validation error 0.3974
# epoch 22.0000, loss 2.1350, train error 0.4090
# epoch 22.0000, validation loss 2.1321, validation error 0.3909
# epoch 23.0000, loss 2.1158, train error 0.4030
# epoch 23.0000, validation loss 2.1125, validation error 0.3837
# epoch 24.0000, loss 2.0950, train error 0.3951
# epoch 24.0000, validation loss 2.0913, validation error 0.3745
# epoch 25.0000, loss 2.0724, train error 0.3876
# epoch 25.0000, validation loss 2.0683, validation error 0.3665
# epoch 26.0000, loss 2.0480, train error 0.3778
# epoch 26.0000, validation loss 2.0436, validation error 0.3564
# epoch 27.0000, loss 2.0219, train error 0.3682
# epoch 27.0000, validation loss 2.0169, validation error 0.3465
# epoch 28.0000, loss 1.9939, train error 0.3593
# epoch 28.0000, validation loss 1.9885, validation error 0.3389
# epoch 29.0000, loss 1.9642, train error 0.3507
# epoch 29.0000, validation loss 1.9582, validation error 0.3286
# epoch 30.0000, loss 1.9327, train error 0.3411
# epoch 30.0000, validation loss 1.9261, validation error 0.3193
# Duration: 233.0s
# ... starting training
# epoch 0.0000, loss 0.1841, train error 0.0555
# epoch 0.0000, validation loss 0.1797, validation error 0.0502
# epoch 1.0000, loss 0.1138, train error 0.0333
# epoch 1.0000, validation loss 0.1253, validation error 0.0341
# epoch 2.0000, loss 0.0850, train error 0.0253
# epoch 2.0000, validation loss 0.1066, validation error 0.0315
# epoch 3.0000, loss 0.0687, train error 0.0211
# epoch 3.0000, validation loss 0.0978, validation error 0.0293
# epoch 4.0000, loss 0.0563, train error 0.0170
# epoch 4.0000, validation loss 0.0927, validation error 0.0265
# epoch 5.0000, loss 0.0457, train error 0.0139
# epoch 5.0000, validation loss 0.0879, validation error 0.0258
# epoch 6.0000, loss 0.0379, train error 0.0116
# epoch 6.0000, validation loss 0.0855, validation error 0.0250
# epoch 7.0000, loss 0.0314, train error 0.0094
# epoch 7.0000, validation loss 0.0830, validation error 0.0235
# epoch 8.0000, loss 0.0248, train error 0.0069
# epoch 8.0000, validation loss 0.0793, validation error 0.0219
# epoch 9.0000, loss 0.0207, train error 0.0057
# epoch 9.0000, validation loss 0.0778, validation error 0.0213
# epoch 10.0000, loss 0.0169, train error 0.0046
# epoch 10.0000, validation loss 0.0772, validation error 0.0204
# epoch 11.0000, loss 0.0139, train error 0.0035
# epoch 11.0000, validation loss 0.0763, validation error 0.0202
# epoch 12.0000, loss 0.0117, train error 0.0026
# epoch 12.0000, validation loss 0.0764, validation error 0.0200
# epoch 13.0000, loss 0.0099, train error 0.0018
# epoch 13.0000, validation loss 0.0762, validation error 0.0197
# epoch 14.0000, loss 0.0086, train error 0.0014
# epoch 14.0000, validation loss 0.0767, validation error 0.0192
# epoch 15.0000, loss 0.0076, train error 0.0012
# epoch 15.0000, validation loss 0.0770, validation error 0.0190
# epoch 16.0000, loss 0.0066, train error 0.0009
# epoch 16.0000, validation loss 0.0775, validation error 0.0186
# epoch 17.0000, loss 0.0058, train error 0.0007
# epoch 17.0000, validation loss 0.0778, validation error 0.0187
# epoch 18.0000, loss 0.0052, train error 0.0007
# epoch 18.0000, validation loss 0.0782, validation error 0.0184
# epoch 19.0000, loss 0.0046, train error 0.0005
# epoch 19.0000, validation loss 0.0787, validation error 0.0186
# epoch 20.0000, loss 0.0041, train error 0.0004
# epoch 20.0000, validation loss 0.0789, validation error 0.0185
# epoch 21.0000, loss 0.0037, train error 0.0003
# epoch 21.0000, validation loss 0.0792, validation error 0.0184
# epoch 22.0000, loss 0.0034, train error 0.0003
# epoch 22.0000, validation loss 0.0793, validation error 0.0183
# epoch 23.0000, loss 0.0030, train error 0.0003
# epoch 23.0000, validation loss 0.0795, validation error 0.0184
# epoch 24.0000, loss 0.0028, train error 0.0002
# epoch 24.0000, validation loss 0.0797, validation error 0.0182
# epoch 25.0000, loss 0.0025, train error 0.0001
# epoch 25.0000, validation loss 0.0800, validation error 0.0184
# epoch 26.0000, loss 0.0023, train error 0.0001
# epoch 26.0000, validation loss 0.0801, validation error 0.0185
# epoch 27.0000, loss 0.0022, train error 0.0000
# epoch 27.0000, validation loss 0.0803, validation error 0.0184
# epoch 28.0000, loss 0.0020, train error 0.0000
# epoch 28.0000, validation loss 0.0804, validation error 0.0183
# epoch 29.0000, loss 0.0019, train error 0.0000
# epoch 29.0000, validation loss 0.0806, validation error 0.0184
# epoch 30.0000, loss 0.0018, train error 0.0000
# epoch 30.0000, validation loss 0.0808, validation error 0.0184
# Duration: 597.2s

# %%
epochs = np.arange(0, max_epochs+1)
plt.plot(epochs, gd_train_error, label = "gd")
plt.plot(epochs, sgd_train_error, label = "sgd")
plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("error")
plt.legend()
plt.title("Optimizer Comparison")
plt.savefig('report/plots/sgd_gd_error.png', dpi=150)
plt.show()
